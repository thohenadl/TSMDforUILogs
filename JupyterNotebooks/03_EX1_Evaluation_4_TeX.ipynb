# %%
import pandas as pd
import numpy as np
pd.set_option("display.float_format", "{:,.2f}".format)
from tabulate import tabulate
rho_value = "06"
encoding = "enc0"

# %% [markdown]
# To be adjusted for the calculation of the Sub-Questions and Response Variables.

# %%
# if encoding is not None:
#     table_source = f"../logs/smartRPA/202511-results/validation_experiment_results_word2vec_safety2_olap08_rho{rho_value}_{encoding}.csv"
# else:
#     table_source = f"../logs/smartRPA/202511-results/validation_experiment_results_word2vec_safety2_olap08_rho{rho_value}.csv"
table_source = f"../logs/smartRPA/202511-results/validation_experiment_results_word2vec_safety2_olap08_rho{rho_value}_enc0_core08.csv"
df = pd.read_csv(table_source)
df.rename(columns={"motif0-length":"motLength","motif0-occurances":"motOcc","motif0-shuffle":"motShuffle"}, inplace=True)

rho_value_id = "rho" + rho_value

# %%
def calculate_classification_metrics(df):
    # Create a copy to avoid SettingWithCopy warnings if the input is a slice
    res_df = df.copy()

    # 1. Recall: TP / (TP + FN)
    # Measures: Out of all the actual motifs in the data, how many did we find?
    res_df["recall"] = res_df["total_tp"] / (res_df["total_tp"] + res_df["total_fn"])

    # 2. Precision: TP / (TP + FP)
    # Measures: Out of all the motifs we claimed to find, how many were actually correct?
    res_df["precision"] = res_df["total_tp"] / (res_df["total_tp"] + res_df["total_fp"])

    # 3. F1-score: Harmonic mean of Precision and Recall
    # Measures: Balance between Precision and Recall.
    res_df["fscore"] = (2 * (res_df["precision"] * res_df["recall"]) / 
                          (res_df["precision"] + res_df["recall"]))

    # Optional: Fill NaN values with 0.0 (happens if denominator is 0)
    res_df[["recall", "precision", "fscore"]] = res_df[["recall", "precision", "fscore"]].fillna(0.0)
    return res_df

# 1. Helper Function to Create Pivot with Counts
def create_pivot_with_count(df, index_col):
    """
    Groups by the index column and calculates:
    - Sum of total_tp, total_fp, total_fn
    - Count of entries (num_entries)
    """
    return df.groupby(index_col).agg(
        total_tp=('total_tp', 'sum'),
        total_fp=('total_fp', 'sum'),
        total_fn=('total_fn', 'sum'),
        num_entries=('total_tp', 'count')  # Counts the number of rows used
    )

# %% [markdown]
# ## Results for all Logs of EX2 based on rho_value

# %%
print("Results from file:")
print(table_source)
print("\n")

pivotPercentage = create_pivot_with_count(df, ["percentageMotifsOverLog"])
# pivotLogLength  = pd.pivot_table(df, index=["logLength"], values=["total_tp","total_fp","total_fn"], aggfunc='sum')
pivotNoOfMotifs = create_pivot_with_count(df, ["noOfMotifs"])
pivotMotOcc     = create_pivot_with_count(df, ["motOcc"])
pivotMotLength  = create_pivot_with_count(df, ["motLength"])
pivotMotShuffle = create_pivot_with_count(df, ["motShuffle"])

list_of_pivots = [pivotPercentage, pivotNoOfMotifs, pivotMotOcc, pivotMotLength, pivotMotShuffle]

for pivot in list_of_pivots: 
    pivot = calculate_classification_metrics(pivot)
    # Assuming 'final_results' is your DataFrame
    print(tabulate(pivot, headers='keys', tablefmt='psql', numalign="right"))
# Out:
# Results from file:
# ../logs/smartRPA/202511-results/validation_experiment_results_word2vec_safety2_olap08_rho06_enc0_core08.csv
#
#
# +---------------------------+------------+------------+------------+---------------+----------+-------------+-----------+
# |   percentageMotifsOverLog |   total_tp |   total_fp |   total_fn |   num_entries |   recall |   precision |    fscore |
# |---------------------------+------------+------------+------------+---------------+----------+-------------+-----------|
# |                         1 |        534 |      26125 |          6 |            41 | 0.988889 |   0.0200308 | 0.0392661 |
# |                        10 |       2646 |      12243 |         99 |           105 | 0.963934 |    0.177715 |  0.300102 |
# |                        25 |       2690 |        608 |        280 |           108 | 0.905724 |    0.815646 |  0.858328 |
# |                        50 |       2143 |        405 |        827 |           108 | 0.721549 |    0.841052 |  0.776731 |
# |                        75 |       1589 |        400 |       1381 |           108 | 0.535017 |    0.798894 |  0.640855 |
# |                       100 |        415 |         58 |       2525 |           107 | 0.141156 |    0.877378 |  0.243188 |
# +---------------------------+------------+------------+------------+---------------+----------+-------------+-----------+
# +--------------+------------+------------+------------+---------------+----------+-------------+----------+
# |   noOfMotifs |   total_tp |   total_fp |   total_fn |   num_entries |   recall |   precision |   fscore |
# |--------------+------------+------------+------------+---------------+----------+-------------+----------|
# |            1 |       1107 |      13215 |        438 |           156 | 0.716505 |   0.0772937 | 0.139535 |
# |            2 |       1918 |       8220 |        872 |           143 | 0.687455 |    0.189189 |  0.29672 |
# |            3 |       2842 |      10087 |       1358 |           143 | 0.676667 |    0.219816 | 0.331835 |
# |            5 |       4150 |       8317 |       2450 |           135 | 0.628788 |    0.332879 | 0.435307 |
# +--------------+------------+------------+------------+---------------+----------+-------------+----------+
# +----------+------------+------------+------------+---------------+----------+-------------+----------+
# |   motOcc |   total_tp |   total_fp |   total_fn |   num_entries |   recall |   precision |   fscore |
# |----------+------------+------------+------------+---------------+----------+-------------+----------|
# |        5 |       1824 |      17290 |        921 |           204 | 0.664481 |   0.0954274 | 0.166888 |
# |       10 |       3449 |      12484 |       1681 |           191 |  0.67232 |    0.216469 | 0.327494 |
# |       15 |       4744 |      10065 |       2516 |           182 | 0.653444 |    0.320346 | 0.429924 |
# +----------+------------+------------+------------+---------------+----------+-------------+----------+
# +-------------+------------+------------+------------+---------------+----------+-------------+----------+
# |   motLength |   total_tp |   total_fp |   total_fn |   num_entries |   recall |   precision |   fscore |
# |-------------+------------+------------+------------+---------------+----------+-------------+----------|
# |          10 |       3433 |      14390 |       1877 |           203 | 0.646516 |    0.192616 | 0.296805 |
# |          20 |       3320 |      14374 |       1795 |           195 | 0.649071 |    0.187634 | 0.291113 |
# |          50 |       3264 |      11075 |       1446 |           179 | 0.692994 |    0.227631 | 0.342695 |
# +-------------+------------+------------+------------+---------------+----------+-------------+----------+
# +--------------+------------+------------+------------+---------------+----------+-------------+----------+
# |   motShuffle |   total_tp |   total_fp |   total_fn |   num_entries |   recall |   precision |   fscore |
# |--------------+------------+------------+------------+---------------+----------+-------------+----------|
# |            0 |       3337 |      13702 |       1728 |           193 | 0.658835 |    0.195845 | 0.301936 |
# |          0.1 |       3417 |      13487 |       1618 |           192 | 0.678649 |    0.202142 |   0.3115 |
# |          0.2 |       3263 |      12650 |       1772 |           192 | 0.648064 |    0.205052 | 0.311533 |
# +--------------+------------+------------+------------+---------------+----------+-------------+----------+

# %% [markdown]
# ## Result Pivots for Filtered 1% and 100% of EX2 based on rho_value

# %%
print("Results from file:")
print(table_source)
print("\n")

dfFilteredOne = df[~df["percentageMotifsOverLog"].isin([1.00,10.00,100.00])]
pivotPercentageFiltered = create_pivot_with_count(dfFilteredOne, ["percentageMotifsOverLog"])
# pivotLogLengthFiltered  = pd.pivot_table(dfFilteredOne, index=["logLength"], values=["total_tp","total_fp","total_fn"], aggfunc='sum')
pivotNoOfMotifsFiltered = create_pivot_with_count(dfFilteredOne, ["noOfMotifs"])
pivotMotOccFiltered     = create_pivot_with_count(dfFilteredOne, ["motOcc"])
pivotMotLengthFiltered  = create_pivot_with_count(dfFilteredOne, ["motLength"])
pivotMotShuffleFiltered = create_pivot_with_count(dfFilteredOne, ["motShuffle"])

list_of_filtered_pivots = [pivotPercentageFiltered, pivotNoOfMotifsFiltered, pivotMotOccFiltered, pivotMotLengthFiltered, pivotMotShuffleFiltered]

for pivot in list_of_filtered_pivots:   
    pivot = calculate_classification_metrics(pivot)
    # 3. (Optional) Keep your visual print if you still want to see it in the console
    print(tabulate(pivot, headers='keys', tablefmt='psql', numalign="right"))
# Out:
# Results from file:
# ../logs/smartRPA/202511-results/validation_experiment_results_word2vec_safety2_olap08_rho06_enc0_core08.csv
#
#
# +---------------------------+------------+------------+------------+---------------+----------+-------------+----------+
# |   percentageMotifsOverLog |   total_tp |   total_fp |   total_fn |   num_entries |   recall |   precision |   fscore |
# |---------------------------+------------+------------+------------+---------------+----------+-------------+----------|
# |                        25 |       2690 |        608 |        280 |           108 | 0.905724 |    0.815646 | 0.858328 |
# |                        50 |       2143 |        405 |        827 |           108 | 0.721549 |    0.841052 | 0.776731 |
# |                        75 |       1589 |        400 |       1381 |           108 | 0.535017 |    0.798894 | 0.640855 |
# +---------------------------+------------+------------+------------+---------------+----------+-------------+----------+
# +--------------+------------+------------+------------+---------------+----------+-------------+----------+
# |   noOfMotifs |   total_tp |   total_fp |   total_fn |   num_entries |   recall |   precision |   fscore |
# |--------------+------------+------------+------------+---------------+----------+-------------+----------|
# |            1 |        631 |         12 |        179 |            81 | 0.779012 |    0.981337 | 0.868548 |
# |            2 |       1200 |        192 |        420 |            81 | 0.740741 |    0.862069 | 0.796813 |
# |            3 |       1814 |        298 |        616 |            81 | 0.746502 |    0.858902 | 0.798767 |
# |            5 |       2777 |        911 |       1273 |            81 | 0.685679 |    0.752983 | 0.717757 |
# +--------------+------------+------------+------------+---------------+----------+-------------+----------+
# +----------+------------+------------+------------+---------------+----------+-------------+----------+
# |   motOcc |   total_tp |   total_fp |   total_fn |   num_entries |   recall |   precision |   fscore |
# |----------+------------+------------+------------+---------------+----------+-------------+----------|
# |        5 |        996 |        192 |        489 |           108 | 0.670707 |    0.838384 |  0.74523 |
# |       10 |       2183 |        467 |        787 |           108 | 0.735017 |    0.823774 | 0.776868 |
# |       15 |       3243 |        754 |       1212 |           108 | 0.727946 |    0.811359 | 0.767392 |
# +----------+------------+------------+------------+---------------+----------+-------------+----------+
# +-------------+------------+------------+------------+---------------+----------+-------------+----------+
# |   motLength |   total_tp |   total_fp |   total_fn |   num_entries |   recall |   precision |   fscore |
# |-------------+------------+------------+------------+---------------+----------+-------------+----------|
# |          10 |       2047 |        273 |        923 |           108 | 0.689226 |    0.882328 | 0.773913 |
# |          20 |       2055 |        443 |        915 |           108 | 0.691919 |    0.822658 | 0.751646 |
# |          50 |       2320 |        697 |        650 |           108 | 0.781145 |    0.768976 | 0.775013 |
# +-------------+------------+------------+------------+---------------+----------+-------------+----------+
# +--------------+------------+------------+------------+---------------+----------+-------------+----------+
# |   motShuffle |   total_tp |   total_fp |   total_fn |   num_entries |   recall |   precision |   fscore |
# |--------------+------------+------------+------------+---------------+----------+-------------+----------|
# |            0 |       2123 |        474 |        847 |           108 | 0.714815 |    0.817482 | 0.762709 |
# |          0.1 |       2203 |        444 |        767 |           108 | 0.741751 |    0.832263 | 0.784404 |
# |          0.2 |       2096 |        495 |        874 |           108 | 0.705724 |    0.808954 | 0.753821 |
# +--------------+------------+------------+------------+---------------+----------+-------------+----------+

# %% [markdown]
# ## Latex Code to be copied into the paper for results (All rho)
#
# Note: Hard Coded Names of Validation Files!

# %%
# ==========================================
# 1. HELPER: Calculate Metrics (Renamed f1score -> fscore)
# ==========================================
def calculate_classification_metrics(df):
    """
    Calculates Precision, Recall, and F-Score.
    Column names generated: 'recall', 'precision', 'fscore'.
    """
    # Avoid division by zero
    df['recall'] = df.apply(lambda row: row['total_tp'] / (row['total_tp'] + row['total_fn']) 
                            if (row['total_tp'] + row['total_fn']) > 0 else 0, axis=1)
    
    df['precision'] = df.apply(lambda row: row['total_tp'] / (row['total_tp'] + row['total_fp']) 
                               if (row['total_tp'] + row['total_fp']) > 0 else 0, axis=1)
    
    # Renamed to 'fscore' to avoid numbers in LaTeX variables
    df['fscore'] = df.apply(lambda row: 2 * (row['precision'] * row['recall']) / (row['precision'] + row['recall']) 
                             if (row['precision'] + row['recall']) > 0 else 0, axis=1)
    return df

# ==========================================
# 2. HELPER: Smart Latex Name Sanitizer
# ==========================================
def sanitize_latex_name(text):
    """
    Converts keys like '09filtered' -> 'ZeroNineFiltered'
    and 'rho06' -> 'RhoZeroSix'.
    """
    clean = str(text)
    
    # 1. Specific fix to ensure 'filtered' becomes 'Filtered' (CamelCase)
    if "filtered" in clean:
        clean = clean.replace("filtered", "Filtered")

    # 2. Map numbers to TitleCase words
    num_map = {
        '0': 'Zero', '1': 'One', '2': 'Two', '3': 'Three', '4': 'Four',
        '5': 'Five', '6': 'Six', '7': 'Seven', '8': 'Eight', '9': 'Nine',
        '.': 'Point'
    }
    for char, word in num_map.items():
        clean = clean.replace(char, word)
    
    # 3. Handle Underscores (Snake_case -> CamelCase)
    if '_' in clean:
        # Capitalize the first letter of each segment
        return "".join(word[0].upper() + word[1:] for word in clean.split('_') if word)
    else:
        # Ensure the very first letter is Capitalized (e.g. fscore -> Fscore)
        return clean[0].upper() + clean[1:]

# ==========================================
# 3. HELPER: Print Pivot Variables
# ==========================================
def print_pivot_variables(df, rho_id):
    metric_name = df.index.name
    # Updated target list to look for 'fscore'
    target_metrics = ['precision', 'recall','fscore']
    
    safe_rho = sanitize_latex_name(rho_id)
    safe_metric_name = sanitize_latex_name(metric_name)

    print(f"% --- {safe_rho} Variables for Index: {metric_name} ---")
    
    for index_val, row in df.iterrows():
        safe_idx = sanitize_latex_name(index_val)
        
        for type_col in target_metrics:
            if type_col in df.columns:
                val = f"{row[type_col]:.3f}"
                safe_type = sanitize_latex_name(type_col) # e.g. fscore -> Fscore
                
                # Name construction: \rhoZeroNineFilteredRecallNoOfMotifsTwo
                var_name = f"{safe_rho}{safe_type}{safe_metric_name}{safe_idx}"
                # Standard convention: first letter lowercase (\rho...)
                var_name = var_name[0].lower() + var_name[1:] 
                
                print(f"\\def\\{var_name}{{{val}}}")
    print("")

# ==========================================
# 4. HELPER: Print Overall Global Variables
# ==========================================
def print_overall_variables(df, rho_id):
    # Sum totals
    total_tp = df["total_tp"].sum()
    total_fp = df["total_fp"].sum()
    total_fn = df["total_fn"].sum()
    
    # Calculate metrics globally
    rec = total_tp / (total_tp + total_fn) if (total_tp + total_fn) > 0 else 0
    prec = total_tp / (total_tp + total_fp) if (total_tp + total_fp) > 0 else 0
    f_score = 2 * (prec * rec) / (prec + rec) if (prec + rec) > 0 else 0
    
    # Updated keys to use 'Fscore'
    metrics = {
        'TotalTp': total_tp, 'TotalFp': total_fp, 'TotalFn': total_fn,
        'Recall': rec, 'Precision': prec, 'Fscore': f_score
    }
    
    safe_rho = sanitize_latex_name(rho_id)
    print(f"% --- {safe_rho} Global Metrics ---")
    
    for name, value in metrics.items():
        formatted_val = f"{int(value)}" if "Total" in name else f"{value:.3f}"
        
        # Name construction: \rhoZeroNineFilteredFscoreOverall
        var_name = f"{safe_rho}{name}Overall"
        var_name = var_name[0].lower() + var_name[1:]
        
        print(f"\\def\\{var_name}{{{formatted_val}}}")
    print("")

# ==========================================
# 5. MAIN EXECUTION FUNCTION
# ==========================================
def generate_full_latex_report(data_dictionary):
    """
    Accepts a dictionary of keys ("06", "09filtered") and dataframes.
    Generates Latex \def commands for all of them using 'Fscore'.
    """
    print("% ========================================================")
    print("% AUTOMATED LATEX VARIABLES GENERATION")
    print("% ========================================================")
    print("")
    
    for key, df in data_dictionary.items():
        # Construct ID: "06" -> "rho06", "06filtered" -> "rho06filtered"
        rho_id = f"rho{key}"
        
        # 1. Global Metrics (Overall sums)
        print_overall_variables(df, rho_id)
        
        # 2. Create Pivots
        pivotPercentage = pd.pivot_table(df, index=["percentageMotifsOverLog"], values=["total_tp","total_fp","total_fn"], aggfunc='sum')
        pivotNoOfMotifs = pd.pivot_table(df, index=["noOfMotifs"], values=["total_tp","total_fp","total_fn"], aggfunc='sum')
        pivotMotOcc     = pd.pivot_table(df, index=["motOcc"], values=["total_tp","total_fp","total_fn"], aggfunc='sum')
        pivotMotLength  = pd.pivot_table(df, index=["motLength"], values=["total_tp","total_fp","total_fn"], aggfunc='sum')
        pivotMotShuffle = pd.pivot_table(df, index=["motShuffle"], values=["total_tp","total_fp","total_fn"], aggfunc='sum')

        list_of_pivots = [pivotPercentage, pivotNoOfMotifs, pivotMotOcc, pivotMotLength, pivotMotShuffle]
        
        # 3. Process Pivots
        for pivot in list_of_pivots:
            pivot = calculate_classification_metrics(pivot)
            print_pivot_variables(pivot, rho_id)
        
        print(f"% --------------------------------------------------------")

# %%
name_06 = f"../logs/smartRPA/202511-results/validation_experiment_results_word2vec_safety2_olap08_rho06_enc0_core08.csv"
name_07 = f"../logs/smartRPA/202511-results/validation_experiment_results_word2vec_safety2_olap08_rho07_enc0_core08.csv"
name_08 = f"../logs/smartRPA/202511-results/validation_experiment_results_word2vec_safety2_olap08_rho08_enc0_core08.csv"
name_09 = f"../logs/smartRPA/202511-results/validation_experiment_results_word2vec_safety2_olap08_rho09_enc0_core08.csv"
df06 = pd.read_csv(name_06)
df07 = pd.read_csv(name_07)
df08 = pd.read_csv(name_08)
df09 = pd.read_csv(name_09)

df06 = df06[~df06["percentageMotifsOverLog"].isin([10.00])]
df07 = df07[~df07["percentageMotifsOverLog"].isin([10.00])]
df08 = df08[~df08["percentageMotifsOverLog"].isin([10.00])]
df09 = df09[~df09["percentageMotifsOverLog"].isin([10.00])]

df06.rename(columns={"motif0-length":"motLength","motif0-occurances":"motOcc","motif0-shuffle":"motShuffle"}, inplace=True)
df07.rename(columns={"motif0-length":"motLength","motif0-occurances":"motOcc","motif0-shuffle":"motShuffle"}, inplace=True)
df08.rename(columns={"motif0-length":"motLength","motif0-occurances":"motOcc","motif0-shuffle":"motShuffle"}, inplace=True)
df09.rename(columns={"motif0-length":"motLength","motif0-occurances":"motOcc","motif0-shuffle":"motShuffle"}, inplace=True)

df06filtered = df06[~df06["percentageMotifsOverLog"].isin([1.00,100.00])]
df07filtered = df07[~df07["percentageMotifsOverLog"].isin([1.00,100.00])]
df08filtered = df08[~df08["percentageMotifsOverLog"].isin([1.00,100.00])]
df09filtered = df09[~df09["percentageMotifsOverLog"].isin([1.00,100.00])]

# REPLACE THESE WITH YOUR ACTUAL DATAFRAMES
data_map = {
    "06": df06,
    "07": df07,
    "08": df08,
    "09": df09,
    "06filtered": df06filtered,
    "07filtered": df07filtered,
    "08filtered": df08filtered,
    "09filtered": df09filtered
}

# Example call (using your current 'df' as a placeholder for all):
generate_full_latex_report(data_map)
# Out:
# % ========================================================
# % AUTOMATED LATEX VARIABLES GENERATION
# % ========================================================
#
# % --- RhoZeroSix Global Metrics ---
# \def\rhoZeroSixTotalTpOverall{7371}
# \def\rhoZeroSixTotalFpOverall{27596}
# \def\rhoZeroSixTotalFnOverall{5019}
# \def\rhoZeroSixRecallOverall{0.595}
# \def\rhoZeroSixPrecisionOverall{0.211}
# \def\rhoZeroSixFscoreOverall{0.311}
#
# % --- RhoZeroSix Variables for Index: percentageMotifsOverLog ---
# \def\rhoZeroSixPrecisionPercentageMotifsOverLogOnePointZero{0.020}
# \def\rhoZeroSixRecallPercentageMotifsOverLogOnePointZero{0.989}
# \def\rhoZeroSixFscorePercentageMotifsOverLogOnePointZero{0.039}
# \def\rhoZeroSixPrecisionPercentageMotifsOverLogTwoFivePointZero{0.816}
# \def\rhoZeroSixRecallPercentageMotifsOverLogTwoFivePointZero{0.906}
# \def\rhoZeroSixFscorePercentageMotifsOverLogTwoFivePointZero{0.858}
# \def\rhoZeroSixPrecisionPercentageMotifsOverLogFiveZeroPointZero{0.841}
# \def\rhoZeroSixRecallPercentageMotifsOverLogFiveZeroPointZero{0.722}
# \def\rhoZeroSixFscorePercentageMotifsOverLogFiveZeroPointZero{0.777}
# \def\rhoZeroSixPrecisionPercentageMotifsOverLogSevenFivePointZero{0.799}
# \def\rhoZeroSixRecallPercentageMotifsOverLogSevenFivePointZero{0.535}
# \def\rhoZeroSixFscorePercentageMotifsOverLogSevenFivePointZero{0.641}
# \def\rhoZeroSixPrecisionPercentageMotifsOverLogOneZeroZeroPointZero{0.877}
# \def\rhoZeroSixRecallPercentageMotifsOverLogOneZeroZeroPointZero{0.141}
# \def\rhoZeroSixFscorePercentageMotifsOverLogOneZeroZeroPointZero{0.243}
#
# % --- RhoZeroSix Variables for Index: noOfMotifs ---
# \def\rhoZeroSixPrecisionNoOfMotifsOnePointZero{0.067}
# \def\rhoZeroSixRecallNoOfMotifsOnePointZero{0.667}
# \def\rhoZeroSixFscoreNoOfMotifsOnePointZero{0.122}
# \def\rhoZeroSixPrecisionNoOfMotifsTwoPointZero{0.197}
# \def\rhoZeroSixRecallNoOfMotifsTwoPointZero{0.618}
# \def\rhoZeroSixFscoreNoOfMotifsTwoPointZero{0.299}
# \def\rhoZeroSixPrecisionNoOfMotifsThreePointZero{0.251}
# \def\rhoZeroSixRecallNoOfMotifsThreePointZero{0.609}
# \def\rhoZeroSixFscoreNoOfMotifsThreePointZero{0.355}
# \def\rhoZeroSixPrecisionNoOfMotifsFivePointZero{0.439}
# \def\rhoZeroSixRecallNoOfMotifsFivePointZero{0.560}
# \def\rhoZeroSixFscoreNoOfMotifsFivePointZero{0.492}
#
# % --- RhoZeroSix Variables for Index: motOcc ---
# \def\rhoZeroSixPrecisionMotOccFivePointZero{0.083}
# \def\rhoZeroSixRecallMotOccFivePointZero{0.600}
# \def\rhoZeroSixFscoreMotOccFivePointZero{0.146}
# \def\rhoZeroSixPrecisionMotOccOneZeroPointZero{0.245}
# \def\rhoZeroSixRecallMotOccOneZeroPointZero{0.603}
# \def\rhoZeroSixFscoreMotOccOneZeroPointZero{0.348}
# \def\rhoZeroSixPrecisionMotOccOneFivePointZero{0.416}
# \def\rhoZeroSixRecallMotOccOneFivePointZero{0.587}
# \def\rhoZeroSixFscoreMotOccOneFivePointZero{0.487}
#
# % --- RhoZeroSix Variables for Index: motLength ---
# \def\rhoZeroSixPrecisionMotLengthOneZeroPointZero{0.164}
# \def\rhoZeroSixRecallMotLengthOneZeroPointZero{0.578}
# \def\rhoZeroSixFscoreMotLengthOneZeroPointZero{0.255}
# \def\rhoZeroSixPrecisionMotLengthTwoZeroPointZero{0.175}
# \def\rhoZeroSixRecallMotLengthTwoZeroPointZero{0.573}
# \def\rhoZeroSixFscoreMotLengthTwoZeroPointZero{0.269}
# \def\rhoZeroSixPrecisionMotLengthFiveZeroPointZero{0.404}
# \def\rhoZeroSixRecallMotLengthFiveZeroPointZero{0.635}
# \def\rhoZeroSixFscoreMotLengthFiveZeroPointZero{0.494}
#
# % --- RhoZeroSix Variables for Index: motShuffle ---
# \def\rhoZeroSixPrecisionMotShuffleZeroPointZero{0.204}
# \def\rhoZeroSixRecallMotShuffleZeroPointZero{0.590}
# \def\rhoZeroSixFscoreMotShuffleZeroPointZero{0.303}
# \def\rhoZeroSixPrecisionMotShuffleZeroPointOne{0.210}
# \def\rhoZeroSixRecallMotShuffleZeroPointOne{0.615}
# \def\rhoZeroSixFscoreMotShuffleZeroPointOne{0.314}
# \def\rhoZeroSixPrecisionMotShuffleZeroPointTwo{0.219}
# \def\rhoZeroSixRecallMotShuffleZeroPointTwo{0.579}
# \def\rhoZeroSixFscoreMotShuffleZeroPointTwo{0.318}
#
# % --------------------------------------------------------
# % --- RhoZeroSeven Global Metrics ---
# \def\rhoZeroSevenTotalTpOverall{8117}
# \def\rhoZeroSevenTotalFpOverall{32462}
# \def\rhoZeroSevenTotalFnOverall{4333}
# \def\rhoZeroSevenRecallOverall{0.652}
# \def\rhoZeroSevenPrecisionOverall{0.200}
# \def\rhoZeroSevenFscoreOverall{0.306}
#
# % --- RhoZeroSeven Variables for Index: percentageMotifsOverLog ---
# \def\rhoZeroSevenPrecisionPercentageMotifsOverLogOnePointZero{0.019}
# \def\rhoZeroSevenRecallPercentageMotifsOverLogOnePointZero{0.997}
# \def\rhoZeroSevenFscorePercentageMotifsOverLogOnePointZero{0.037}
# \def\rhoZeroSevenPrecisionPercentageMotifsOverLogTwoFivePointZero{0.811}
# \def\rhoZeroSevenRecallPercentageMotifsOverLogTwoFivePointZero{0.954}
# \def\rhoZeroSevenFscorePercentageMotifsOverLogTwoFivePointZero{0.876}
# \def\rhoZeroSevenPrecisionPercentageMotifsOverLogFiveZeroPointZero{0.841}
# \def\rhoZeroSevenRecallPercentageMotifsOverLogFiveZeroPointZero{0.771}
# \def\rhoZeroSevenFscorePercentageMotifsOverLogFiveZeroPointZero{0.804}
# \def\rhoZeroSevenPrecisionPercentageMotifsOverLogSevenFivePointZero{0.817}
# \def\rhoZeroSevenRecallPercentageMotifsOverLogSevenFivePointZero{0.651}
# \def\rhoZeroSevenFscorePercentageMotifsOverLogSevenFivePointZero{0.724}
# \def\rhoZeroSevenPrecisionPercentageMotifsOverLogOneZeroZeroPointZero{0.866}
# \def\rhoZeroSevenRecallPercentageMotifsOverLogOneZeroZeroPointZero{0.158}
# \def\rhoZeroSevenFscorePercentageMotifsOverLogOneZeroZeroPointZero{0.267}
#
# % --- RhoZeroSeven Variables for Index: noOfMotifs ---
# \def\rhoZeroSevenPrecisionNoOfMotifsOnePointZero{0.066}
# \def\rhoZeroSevenRecallNoOfMotifsOnePointZero{0.736}
# \def\rhoZeroSevenFscoreNoOfMotifsOnePointZero{0.122}
# \def\rhoZeroSevenPrecisionNoOfMotifsTwoPointZero{0.153}
# \def\rhoZeroSevenRecallNoOfMotifsTwoPointZero{0.647}
# \def\rhoZeroSevenFscoreNoOfMotifsTwoPointZero{0.247}
# \def\rhoZeroSevenPrecisionNoOfMotifsThreePointZero{0.244}
# \def\rhoZeroSevenRecallNoOfMotifsThreePointZero{0.650}
# \def\rhoZeroSevenFscoreNoOfMotifsThreePointZero{0.354}
# \def\rhoZeroSevenPrecisionNoOfMotifsFivePointZero{0.456}
# \def\rhoZeroSevenRecallNoOfMotifsFivePointZero{0.636}
# \def\rhoZeroSevenFscoreNoOfMotifsFivePointZero{0.531}
#
# % --- RhoZeroSeven Variables for Index: motOcc ---
# \def\rhoZeroSevenPrecisionMotOccFivePointZero{0.084}
# \def\rhoZeroSevenRecallMotOccFivePointZero{0.669}
# \def\rhoZeroSevenFscoreMotOccFivePointZero{0.149}
# \def\rhoZeroSevenPrecisionMotOccOneZeroPointZero{0.241}
# \def\rhoZeroSevenRecallMotOccOneZeroPointZero{0.659}
# \def\rhoZeroSevenFscoreMotOccOneZeroPointZero{0.353}
# \def\rhoZeroSevenPrecisionMotOccOneFivePointZero{0.344}
# \def\rhoZeroSevenRecallMotOccOneFivePointZero{0.641}
# \def\rhoZeroSevenFscoreMotOccOneFivePointZero{0.448}
#
# % --- RhoZeroSeven Variables for Index: motLength ---
# \def\rhoZeroSevenPrecisionMotLengthOneZeroPointZero{0.147}
# \def\rhoZeroSevenRecallMotLengthOneZeroPointZero{0.634}
# \def\rhoZeroSevenFscoreMotLengthOneZeroPointZero{0.238}
# \def\rhoZeroSevenPrecisionMotLengthTwoZeroPointZero{0.170}
# \def\rhoZeroSevenRecallMotLengthTwoZeroPointZero{0.619}
# \def\rhoZeroSevenFscoreMotLengthTwoZeroPointZero{0.267}
# \def\rhoZeroSevenPrecisionMotLengthFiveZeroPointZero{0.419}
# \def\rhoZeroSevenRecallMotLengthFiveZeroPointZero{0.707}
# \def\rhoZeroSevenFscoreMotLengthFiveZeroPointZero{0.526}
#
# % --- RhoZeroSeven Variables for Index: motShuffle ---
# \def\rhoZeroSevenPrecisionMotShuffleZeroPointZero{0.205}
# \def\rhoZeroSevenRecallMotShuffleZeroPointZero{0.652}
# \def\rhoZeroSevenFscoreMotShuffleZeroPointZero{0.312}
# \def\rhoZeroSevenPrecisionMotShuffleZeroPointOne{0.195}
# \def\rhoZeroSevenRecallMotShuffleZeroPointOne{0.663}
# \def\rhoZeroSevenFscoreMotShuffleZeroPointOne{0.301}
# \def\rhoZeroSevenPrecisionMotShuffleZeroPointTwo{0.201}
# \def\rhoZeroSevenRecallMotShuffleZeroPointTwo{0.641}
# \def\rhoZeroSevenFscoreMotShuffleZeroPointTwo{0.306}
#
# % --------------------------------------------------------
# % --- RhoZeroEight Global Metrics ---
# \def\rhoZeroEightTotalTpOverall{8196}
# \def\rhoZeroEightTotalFpOverall{10660}
# \def\rhoZeroEightTotalFnOverall{3844}
# \def\rhoZeroEightRecallOverall{0.681}
# \def\rhoZeroEightPrecisionOverall{0.435}
# \def\rhoZeroEightFscoreOverall{0.531}
#
# % --- RhoZeroEight Variables for Index: percentageMotifsOverLog ---
# \def\rhoZeroEightPrecisionPercentageMotifsOverLogOnePointZero{0.021}
# \def\rhoZeroEightRecallPercentageMotifsOverLogOnePointZero{1.000}
# \def\rhoZeroEightFscorePercentageMotifsOverLogOnePointZero{0.041}
# \def\rhoZeroEightPrecisionPercentageMotifsOverLogTwoFivePointZero{0.791}
# \def\rhoZeroEightRecallPercentageMotifsOverLogTwoFivePointZero{0.956}
# \def\rhoZeroEightFscorePercentageMotifsOverLogTwoFivePointZero{0.866}
# \def\rhoZeroEightPrecisionPercentageMotifsOverLogFiveZeroPointZero{0.850}
# \def\rhoZeroEightRecallPercentageMotifsOverLogFiveZeroPointZero{0.833}
# \def\rhoZeroEightFscorePercentageMotifsOverLogFiveZeroPointZero{0.841}
# \def\rhoZeroEightPrecisionPercentageMotifsOverLogSevenFivePointZero{0.819}
# \def\rhoZeroEightRecallPercentageMotifsOverLogSevenFivePointZero{0.743}
# \def\rhoZeroEightFscorePercentageMotifsOverLogSevenFivePointZero{0.779}
# \def\rhoZeroEightPrecisionPercentageMotifsOverLogOneZeroZeroPointZero{0.851}
# \def\rhoZeroEightRecallPercentageMotifsOverLogOneZeroZeroPointZero{0.166}
# \def\rhoZeroEightFscorePercentageMotifsOverLogOneZeroZeroPointZero{0.277}
#
# % --- RhoZeroEight Variables for Index: noOfMotifs ---
# \def\rhoZeroEightPrecisionNoOfMotifsOnePointZero{0.162}
# \def\rhoZeroEightRecallNoOfMotifsOnePointZero{0.788}
# \def\rhoZeroEightFscoreNoOfMotifsOnePointZero{0.268}
# \def\rhoZeroEightPrecisionNoOfMotifsTwoPointZero{0.400}
# \def\rhoZeroEightRecallNoOfMotifsTwoPointZero{0.709}
# \def\rhoZeroEightFscoreNoOfMotifsTwoPointZero{0.511}
# \def\rhoZeroEightPrecisionNoOfMotifsThreePointZero{0.463}
# \def\rhoZeroEightRecallNoOfMotifsThreePointZero{0.646}
# \def\rhoZeroEightFscoreNoOfMotifsThreePointZero{0.540}
# \def\rhoZeroEightPrecisionNoOfMotifsFivePointZero{0.775}
# \def\rhoZeroEightRecallNoOfMotifsFivePointZero{0.667}
# \def\rhoZeroEightFscoreNoOfMotifsFivePointZero{0.717}
#
# % --- RhoZeroEight Variables for Index: motOcc ---
# \def\rhoZeroEightPrecisionMotOccFivePointZero{0.193}
# \def\rhoZeroEightRecallMotOccFivePointZero{0.685}
# \def\rhoZeroEightFscoreMotOccFivePointZero{0.301}
# \def\rhoZeroEightPrecisionMotOccOneZeroPointZero{0.615}
# \def\rhoZeroEightRecallMotOccOneZeroPointZero{0.683}
# \def\rhoZeroEightFscoreMotOccOneZeroPointZero{0.647}
# \def\rhoZeroEightPrecisionMotOccOneFivePointZero{0.579}
# \def\rhoZeroEightRecallMotOccOneFivePointZero{0.677}
# \def\rhoZeroEightFscoreMotOccOneFivePointZero{0.624}
#
# % --- RhoZeroEight Variables for Index: motLength ---
# \def\rhoZeroEightPrecisionMotLengthOneZeroPointZero{0.262}
# \def\rhoZeroEightRecallMotLengthOneZeroPointZero{0.636}
# \def\rhoZeroEightFscoreMotLengthOneZeroPointZero{0.371}
# \def\rhoZeroEightPrecisionMotLengthTwoZeroPointZero{0.493}
# \def\rhoZeroEightRecallMotLengthTwoZeroPointZero{0.671}
# \def\rhoZeroEightFscoreMotLengthTwoZeroPointZero{0.568}
# \def\rhoZeroEightPrecisionMotLengthFiveZeroPointZero{0.848}
# \def\rhoZeroEightRecallMotLengthFiveZeroPointZero{0.738}
# \def\rhoZeroEightFscoreMotLengthFiveZeroPointZero{0.789}
#
# % --- RhoZeroEight Variables for Index: motShuffle ---
# \def\rhoZeroEightPrecisionMotShuffleZeroPointZero{0.467}
# \def\rhoZeroEightRecallMotShuffleZeroPointZero{0.691}
# \def\rhoZeroEightFscoreMotShuffleZeroPointZero{0.558}
# \def\rhoZeroEightPrecisionMotShuffleZeroPointOne{0.384}
# \def\rhoZeroEightRecallMotShuffleZeroPointOne{0.662}
# \def\rhoZeroEightFscoreMotShuffleZeroPointOne{0.486}
# \def\rhoZeroEightPrecisionMotShuffleZeroPointTwo{0.460}
# \def\rhoZeroEightRecallMotShuffleZeroPointTwo{0.689}
# \def\rhoZeroEightFscoreMotShuffleZeroPointTwo{0.552}
#
# % --------------------------------------------------------
# % --- RhoZeroNine Global Metrics ---
# \def\rhoZeroNineTotalTpOverall{7728}
# \def\rhoZeroNineTotalFpOverall{6901}
# \def\rhoZeroNineTotalFnOverall{4197}
# \def\rhoZeroNineRecallOverall{0.648}
# \def\rhoZeroNinePrecisionOverall{0.528}
# \def\rhoZeroNineFscoreOverall{0.582}
#
# % --- RhoZeroNine Variables for Index: percentageMotifsOverLog ---
# \def\rhoZeroNinePrecisionPercentageMotifsOverLogOnePointZero{0.025}
# \def\rhoZeroNineRecallPercentageMotifsOverLogOnePointZero{1.000}
# \def\rhoZeroNineFscorePercentageMotifsOverLogOnePointZero{0.048}
# \def\rhoZeroNinePrecisionPercentageMotifsOverLogTwoFivePointZero{0.805}
# \def\rhoZeroNineRecallPercentageMotifsOverLogTwoFivePointZero{0.949}
# \def\rhoZeroNineFscorePercentageMotifsOverLogTwoFivePointZero{0.871}
# \def\rhoZeroNinePrecisionPercentageMotifsOverLogFiveZeroPointZero{0.776}
# \def\rhoZeroNineRecallPercentageMotifsOverLogFiveZeroPointZero{0.766}
# \def\rhoZeroNineFscorePercentageMotifsOverLogFiveZeroPointZero{0.771}
# \def\rhoZeroNinePrecisionPercentageMotifsOverLogSevenFivePointZero{0.773}
# \def\rhoZeroNineRecallPercentageMotifsOverLogSevenFivePointZero{0.703}
# \def\rhoZeroNineFscorePercentageMotifsOverLogSevenFivePointZero{0.736}
# \def\rhoZeroNinePrecisionPercentageMotifsOverLogOneZeroZeroPointZero{0.693}
# \def\rhoZeroNineRecallPercentageMotifsOverLogOneZeroZeroPointZero{0.167}
# \def\rhoZeroNineFscorePercentageMotifsOverLogOneZeroZeroPointZero{0.270}
#
# % --- RhoZeroNine Variables for Index: noOfMotifs ---
# \def\rhoZeroNinePrecisionNoOfMotifsOnePointZero{0.259}
# \def\rhoZeroNineRecallNoOfMotifsOnePointZero{0.782}
# \def\rhoZeroNineFscoreNoOfMotifsOnePointZero{0.389}
# \def\rhoZeroNinePrecisionNoOfMotifsTwoPointZero{0.512}
# \def\rhoZeroNineRecallNoOfMotifsTwoPointZero{0.654}
# \def\rhoZeroNineFscoreNoOfMotifsTwoPointZero{0.574}
# \def\rhoZeroNinePrecisionNoOfMotifsThreePointZero{0.546}
# \def\rhoZeroNineRecallNoOfMotifsThreePointZero{0.635}
# \def\rhoZeroNineFscoreNoOfMotifsThreePointZero{0.587}
# \def\rhoZeroNinePrecisionNoOfMotifsFivePointZero{0.726}
# \def\rhoZeroNineRecallNoOfMotifsFivePointZero{0.625}
# \def\rhoZeroNineFscoreNoOfMotifsFivePointZero{0.672}
#
# % --- RhoZeroNine Variables for Index: motOcc ---
# \def\rhoZeroNinePrecisionMotOccFivePointZero{0.246}
# \def\rhoZeroNineRecallMotOccFivePointZero{0.635}
# \def\rhoZeroNineFscoreMotOccFivePointZero{0.354}
# \def\rhoZeroNinePrecisionMotOccOneZeroPointZero{0.585}
# \def\rhoZeroNineRecallMotOccOneZeroPointZero{0.639}
# \def\rhoZeroNineFscoreMotOccOneZeroPointZero{0.611}
# \def\rhoZeroNinePrecisionMotOccOneFivePointZero{0.785}
# \def\rhoZeroNineRecallMotOccOneFivePointZero{0.659}
# \def\rhoZeroNineFscoreMotOccOneFivePointZero{0.717}
#
# % --- RhoZeroNine Variables for Index: motLength ---
# \def\rhoZeroNinePrecisionMotLengthOneZeroPointZero{0.381}
# \def\rhoZeroNineRecallMotLengthOneZeroPointZero{0.644}
# \def\rhoZeroNineFscoreMotLengthOneZeroPointZero{0.479}
# \def\rhoZeroNinePrecisionMotLengthTwoZeroPointZero{0.654}
# \def\rhoZeroNineRecallMotLengthTwoZeroPointZero{0.717}
# \def\rhoZeroNineFscoreMotLengthTwoZeroPointZero{0.684}
# \def\rhoZeroNinePrecisionMotLengthFiveZeroPointZero{0.665}
# \def\rhoZeroNineRecallMotLengthFiveZeroPointZero{0.582}
# \def\rhoZeroNineFscoreMotLengthFiveZeroPointZero{0.620}
#
# % --- RhoZeroNine Variables for Index: motShuffle ---
# \def\rhoZeroNinePrecisionMotShuffleZeroPointZero{0.577}
# \def\rhoZeroNineRecallMotShuffleZeroPointZero{0.652}
# \def\rhoZeroNineFscoreMotShuffleZeroPointZero{0.612}
# \def\rhoZeroNinePrecisionMotShuffleZeroPointOne{0.496}
# \def\rhoZeroNineRecallMotShuffleZeroPointOne{0.631}
# \def\rhoZeroNineFscoreMotShuffleZeroPointOne{0.555}
# \def\rhoZeroNinePrecisionMotShuffleZeroPointTwo{0.517}
# \def\rhoZeroNineRecallMotShuffleZeroPointTwo{0.661}
# \def\rhoZeroNineFscoreMotShuffleZeroPointTwo{0.581}
#
# % --------------------------------------------------------
# % --- RhoZeroSixFiltered Global Metrics ---
# \def\rhoZeroSixFilteredTotalTpOverall{6422}
# \def\rhoZeroSixFilteredTotalFpOverall{1413}
# \def\rhoZeroSixFilteredTotalFnOverall{2488}
# \def\rhoZeroSixFilteredRecallOverall{0.721}
# \def\rhoZeroSixFilteredPrecisionOverall{0.820}
# \def\rhoZeroSixFilteredFscoreOverall{0.767}
#
# % --- RhoZeroSixFiltered Variables for Index: percentageMotifsOverLog ---
# \def\rhoZeroSixFilteredPrecisionPercentageMotifsOverLogTwoFivePointZero{0.816}
# \def\rhoZeroSixFilteredRecallPercentageMotifsOverLogTwoFivePointZero{0.906}
# \def\rhoZeroSixFilteredFscorePercentageMotifsOverLogTwoFivePointZero{0.858}
# \def\rhoZeroSixFilteredPrecisionPercentageMotifsOverLogFiveZeroPointZero{0.841}
# \def\rhoZeroSixFilteredRecallPercentageMotifsOverLogFiveZeroPointZero{0.722}
# \def\rhoZeroSixFilteredFscorePercentageMotifsOverLogFiveZeroPointZero{0.777}
# \def\rhoZeroSixFilteredPrecisionPercentageMotifsOverLogSevenFivePointZero{0.799}
# \def\rhoZeroSixFilteredRecallPercentageMotifsOverLogSevenFivePointZero{0.535}
# \def\rhoZeroSixFilteredFscorePercentageMotifsOverLogSevenFivePointZero{0.641}
#
# % --- RhoZeroSixFiltered Variables for Index: noOfMotifs ---
# \def\rhoZeroSixFilteredPrecisionNoOfMotifsOnePointZero{0.981}
# \def\rhoZeroSixFilteredRecallNoOfMotifsOnePointZero{0.779}
# \def\rhoZeroSixFilteredFscoreNoOfMotifsOnePointZero{0.869}
# \def\rhoZeroSixFilteredPrecisionNoOfMotifsTwoPointZero{0.862}
# \def\rhoZeroSixFilteredRecallNoOfMotifsTwoPointZero{0.741}
# \def\rhoZeroSixFilteredFscoreNoOfMotifsTwoPointZero{0.797}
# \def\rhoZeroSixFilteredPrecisionNoOfMotifsThreePointZero{0.859}
# \def\rhoZeroSixFilteredRecallNoOfMotifsThreePointZero{0.747}
# \def\rhoZeroSixFilteredFscoreNoOfMotifsThreePointZero{0.799}
# \def\rhoZeroSixFilteredPrecisionNoOfMotifsFivePointZero{0.753}
# \def\rhoZeroSixFilteredRecallNoOfMotifsFivePointZero{0.686}
# \def\rhoZeroSixFilteredFscoreNoOfMotifsFivePointZero{0.718}
#
# % --- RhoZeroSixFiltered Variables for Index: motOcc ---
# \def\rhoZeroSixFilteredPrecisionMotOccFivePointZero{0.838}
# \def\rhoZeroSixFilteredRecallMotOccFivePointZero{0.671}
# \def\rhoZeroSixFilteredFscoreMotOccFivePointZero{0.745}
# \def\rhoZeroSixFilteredPrecisionMotOccOneZeroPointZero{0.824}
# \def\rhoZeroSixFilteredRecallMotOccOneZeroPointZero{0.735}
# \def\rhoZeroSixFilteredFscoreMotOccOneZeroPointZero{0.777}
# \def\rhoZeroSixFilteredPrecisionMotOccOneFivePointZero{0.811}
# \def\rhoZeroSixFilteredRecallMotOccOneFivePointZero{0.728}
# \def\rhoZeroSixFilteredFscoreMotOccOneFivePointZero{0.767}
#
# % --- RhoZeroSixFiltered Variables for Index: motLength ---
# \def\rhoZeroSixFilteredPrecisionMotLengthOneZeroPointZero{0.882}
# \def\rhoZeroSixFilteredRecallMotLengthOneZeroPointZero{0.689}
# \def\rhoZeroSixFilteredFscoreMotLengthOneZeroPointZero{0.774}
# \def\rhoZeroSixFilteredPrecisionMotLengthTwoZeroPointZero{0.823}
# \def\rhoZeroSixFilteredRecallMotLengthTwoZeroPointZero{0.692}
# \def\rhoZeroSixFilteredFscoreMotLengthTwoZeroPointZero{0.752}
# \def\rhoZeroSixFilteredPrecisionMotLengthFiveZeroPointZero{0.769}
# \def\rhoZeroSixFilteredRecallMotLengthFiveZeroPointZero{0.781}
# \def\rhoZeroSixFilteredFscoreMotLengthFiveZeroPointZero{0.775}
#
# % --- RhoZeroSixFiltered Variables for Index: motShuffle ---
# \def\rhoZeroSixFilteredPrecisionMotShuffleZeroPointZero{0.817}
# \def\rhoZeroSixFilteredRecallMotShuffleZeroPointZero{0.715}
# \def\rhoZeroSixFilteredFscoreMotShuffleZeroPointZero{0.763}
# \def\rhoZeroSixFilteredPrecisionMotShuffleZeroPointOne{0.832}
# \def\rhoZeroSixFilteredRecallMotShuffleZeroPointOne{0.742}
# \def\rhoZeroSixFilteredFscoreMotShuffleZeroPointOne{0.784}
# \def\rhoZeroSixFilteredPrecisionMotShuffleZeroPointTwo{0.809}
# \def\rhoZeroSixFilteredRecallMotShuffleZeroPointTwo{0.706}
# \def\rhoZeroSixFilteredFscoreMotShuffleZeroPointTwo{0.754}
#
# % --------------------------------------------------------
# % --- RhoZeroSevenFiltered Global Metrics ---
# \def\rhoZeroSevenFilteredTotalTpOverall{7054}
# \def\rhoZeroSevenFilteredTotalFpOverall{1530}
# \def\rhoZeroSevenFilteredTotalFnOverall{1856}
# \def\rhoZeroSevenFilteredRecallOverall{0.792}
# \def\rhoZeroSevenFilteredPrecisionOverall{0.822}
# \def\rhoZeroSevenFilteredFscoreOverall{0.806}
#
# % --- RhoZeroSevenFiltered Variables for Index: percentageMotifsOverLog ---
# \def\rhoZeroSevenFilteredPrecisionPercentageMotifsOverLogTwoFivePointZero{0.811}
# \def\rhoZeroSevenFilteredRecallPercentageMotifsOverLogTwoFivePointZero{0.954}
# \def\rhoZeroSevenFilteredFscorePercentageMotifsOverLogTwoFivePointZero{0.876}
# \def\rhoZeroSevenFilteredPrecisionPercentageMotifsOverLogFiveZeroPointZero{0.841}
# \def\rhoZeroSevenFilteredRecallPercentageMotifsOverLogFiveZeroPointZero{0.771}
# \def\rhoZeroSevenFilteredFscorePercentageMotifsOverLogFiveZeroPointZero{0.804}
# \def\rhoZeroSevenFilteredPrecisionPercentageMotifsOverLogSevenFivePointZero{0.817}
# \def\rhoZeroSevenFilteredRecallPercentageMotifsOverLogSevenFivePointZero{0.651}
# \def\rhoZeroSevenFilteredFscorePercentageMotifsOverLogSevenFivePointZero{0.724}
#
# % --- RhoZeroSevenFiltered Variables for Index: noOfMotifs ---
# \def\rhoZeroSevenFilteredPrecisionNoOfMotifsOnePointZero{0.990}
# \def\rhoZeroSevenFilteredRecallNoOfMotifsOnePointZero{0.886}
# \def\rhoZeroSevenFilteredFscoreNoOfMotifsOnePointZero{0.936}
# \def\rhoZeroSevenFilteredPrecisionNoOfMotifsTwoPointZero{0.811}
# \def\rhoZeroSevenFilteredRecallNoOfMotifsTwoPointZero{0.762}
# \def\rhoZeroSevenFilteredFscoreNoOfMotifsTwoPointZero{0.786}
# \def\rhoZeroSevenFilteredPrecisionNoOfMotifsThreePointZero{0.841}
# \def\rhoZeroSevenFilteredRecallNoOfMotifsThreePointZero{0.794}
# \def\rhoZeroSevenFilteredFscoreNoOfMotifsThreePointZero{0.817}
# \def\rhoZeroSevenFilteredPrecisionNoOfMotifsFivePointZero{0.785}
# \def\rhoZeroSevenFilteredRecallNoOfMotifsFivePointZero{0.783}
# \def\rhoZeroSevenFilteredFscoreNoOfMotifsFivePointZero{0.784}
#
# % --- RhoZeroSevenFiltered Variables for Index: motOcc ---
# \def\rhoZeroSevenFilteredPrecisionMotOccFivePointZero{0.860}
# \def\rhoZeroSevenFilteredRecallMotOccFivePointZero{0.768}
# \def\rhoZeroSevenFilteredFscoreMotOccFivePointZero{0.811}
# \def\rhoZeroSevenFilteredPrecisionMotOccOneZeroPointZero{0.821}
# \def\rhoZeroSevenFilteredRecallMotOccOneZeroPointZero{0.802}
# \def\rhoZeroSevenFilteredFscoreMotOccOneZeroPointZero{0.811}
# \def\rhoZeroSevenFilteredPrecisionMotOccOneFivePointZero{0.811}
# \def\rhoZeroSevenFilteredRecallMotOccOneFivePointZero{0.793}
# \def\rhoZeroSevenFilteredFscoreMotOccOneFivePointZero{0.802}
#
# % --- RhoZeroSevenFiltered Variables for Index: motLength ---
# \def\rhoZeroSevenFilteredPrecisionMotLengthOneZeroPointZero{0.844}
# \def\rhoZeroSevenFilteredRecallMotLengthOneZeroPointZero{0.755}
# \def\rhoZeroSevenFilteredFscoreMotLengthOneZeroPointZero{0.797}
# \def\rhoZeroSevenFilteredPrecisionMotLengthTwoZeroPointZero{0.797}
# \def\rhoZeroSevenFilteredRecallMotLengthTwoZeroPointZero{0.752}
# \def\rhoZeroSevenFilteredFscoreMotLengthTwoZeroPointZero{0.774}
# \def\rhoZeroSevenFilteredPrecisionMotLengthFiveZeroPointZero{0.825}
# \def\rhoZeroSevenFilteredRecallMotLengthFiveZeroPointZero{0.868}
# \def\rhoZeroSevenFilteredFscoreMotLengthFiveZeroPointZero{0.846}
#
# % --- RhoZeroSevenFiltered Variables for Index: motShuffle ---
# \def\rhoZeroSevenFilteredPrecisionMotShuffleZeroPointZero{0.827}
# \def\rhoZeroSevenFilteredRecallMotShuffleZeroPointZero{0.799}
# \def\rhoZeroSevenFilteredFscoreMotShuffleZeroPointZero{0.812}
# \def\rhoZeroSevenFilteredPrecisionMotShuffleZeroPointOne{0.823}
# \def\rhoZeroSevenFilteredRecallMotShuffleZeroPointOne{0.796}
# \def\rhoZeroSevenFilteredFscoreMotShuffleZeroPointOne{0.809}
# \def\rhoZeroSevenFilteredPrecisionMotShuffleZeroPointTwo{0.816}
# \def\rhoZeroSevenFilteredRecallMotShuffleZeroPointTwo{0.780}
# \def\rhoZeroSevenFilteredFscoreMotShuffleZeroPointTwo{0.798}
#
# % --------------------------------------------------------
# % --- RhoZeroEightFiltered Global Metrics ---
# \def\rhoZeroEightFilteredTotalTpOverall{7519}
# \def\rhoZeroEightFilteredTotalFpOverall{1676}
# \def\rhoZeroEightFilteredTotalFnOverall{1391}
# \def\rhoZeroEightFilteredRecallOverall{0.844}
# \def\rhoZeroEightFilteredPrecisionOverall{0.818}
# \def\rhoZeroEightFilteredFscoreOverall{0.831}
#
# % --- RhoZeroEightFiltered Variables for Index: percentageMotifsOverLog ---
# \def\rhoZeroEightFilteredPrecisionPercentageMotifsOverLogTwoFivePointZero{0.791}
# \def\rhoZeroEightFilteredRecallPercentageMotifsOverLogTwoFivePointZero{0.956}
# \def\rhoZeroEightFilteredFscorePercentageMotifsOverLogTwoFivePointZero{0.866}
# \def\rhoZeroEightFilteredPrecisionPercentageMotifsOverLogFiveZeroPointZero{0.850}
# \def\rhoZeroEightFilteredRecallPercentageMotifsOverLogFiveZeroPointZero{0.833}
# \def\rhoZeroEightFilteredFscorePercentageMotifsOverLogFiveZeroPointZero{0.841}
# \def\rhoZeroEightFilteredPrecisionPercentageMotifsOverLogSevenFivePointZero{0.819}
# \def\rhoZeroEightFilteredRecallPercentageMotifsOverLogSevenFivePointZero{0.743}
# \def\rhoZeroEightFilteredFscorePercentageMotifsOverLogSevenFivePointZero{0.779}
#
# % --- RhoZeroEightFiltered Variables for Index: noOfMotifs ---
# \def\rhoZeroEightFilteredPrecisionNoOfMotifsOnePointZero{0.993}
# \def\rhoZeroEightFilteredRecallNoOfMotifsOnePointZero{0.990}
# \def\rhoZeroEightFilteredFscoreNoOfMotifsOnePointZero{0.991}
# \def\rhoZeroEightFilteredPrecisionNoOfMotifsTwoPointZero{0.882}
# \def\rhoZeroEightFilteredRecallNoOfMotifsTwoPointZero{0.875}
# \def\rhoZeroEightFilteredFscoreNoOfMotifsTwoPointZero{0.879}
# \def\rhoZeroEightFilteredPrecisionNoOfMotifsThreePointZero{0.799}
# \def\rhoZeroEightFilteredRecallNoOfMotifsThreePointZero{0.814}
# \def\rhoZeroEightFilteredFscoreNoOfMotifsThreePointZero{0.806}
# \def\rhoZeroEightFilteredPrecisionNoOfMotifsFivePointZero{0.772}
# \def\rhoZeroEightFilteredRecallNoOfMotifsFivePointZero{0.820}
# \def\rhoZeroEightFilteredFscoreNoOfMotifsFivePointZero{0.795}
#
# % --- RhoZeroEightFiltered Variables for Index: motOcc ---
# \def\rhoZeroEightFilteredPrecisionMotOccFivePointZero{0.851}
# \def\rhoZeroEightFilteredRecallMotOccFivePointZero{0.822}
# \def\rhoZeroEightFilteredFscoreMotOccFivePointZero{0.836}
# \def\rhoZeroEightFilteredPrecisionMotOccOneZeroPointZero{0.832}
# \def\rhoZeroEightFilteredRecallMotOccOneZeroPointZero{0.858}
# \def\rhoZeroEightFilteredFscoreMotOccOneZeroPointZero{0.845}
# \def\rhoZeroEightFilteredPrecisionMotOccOneFivePointZero{0.798}
# \def\rhoZeroEightFilteredRecallMotOccOneFivePointZero{0.842}
# \def\rhoZeroEightFilteredFscoreMotOccOneFivePointZero{0.819}
#
# % --- RhoZeroEightFiltered Variables for Index: motLength ---
# \def\rhoZeroEightFilteredPrecisionMotLengthOneZeroPointZero{0.792}
# \def\rhoZeroEightFilteredRecallMotLengthOneZeroPointZero{0.784}
# \def\rhoZeroEightFilteredFscoreMotLengthOneZeroPointZero{0.788}
# \def\rhoZeroEightFilteredPrecisionMotLengthTwoZeroPointZero{0.806}
# \def\rhoZeroEightFilteredRecallMotLengthTwoZeroPointZero{0.836}
# \def\rhoZeroEightFilteredFscoreMotLengthTwoZeroPointZero{0.821}
# \def\rhoZeroEightFilteredPrecisionMotLengthFiveZeroPointZero{0.853}
# \def\rhoZeroEightFilteredRecallMotLengthFiveZeroPointZero{0.911}
# \def\rhoZeroEightFilteredFscoreMotLengthFiveZeroPointZero{0.881}
#
# % --- RhoZeroEightFiltered Variables for Index: motShuffle ---
# \def\rhoZeroEightFilteredPrecisionMotShuffleZeroPointZero{0.837}
# \def\rhoZeroEightFilteredRecallMotShuffleZeroPointZero{0.865}
# \def\rhoZeroEightFilteredFscoreMotShuffleZeroPointZero{0.851}
# \def\rhoZeroEightFilteredPrecisionMotShuffleZeroPointOne{0.789}
# \def\rhoZeroEightFilteredRecallMotShuffleZeroPointOne{0.807}
# \def\rhoZeroEightFilteredFscoreMotShuffleZeroPointOne{0.798}
# \def\rhoZeroEightFilteredPrecisionMotShuffleZeroPointTwo{0.827}
# \def\rhoZeroEightFilteredRecallMotShuffleZeroPointTwo{0.860}
# \def\rhoZeroEightFilteredFscoreMotShuffleZeroPointTwo{0.843}
#
# % --------------------------------------------------------
# % --- RhoZeroNineFiltered Global Metrics ---
# \def\rhoZeroNineFilteredTotalTpOverall{7111}
# \def\rhoZeroNineFilteredTotalFpOverall{1935}
# \def\rhoZeroNineFilteredTotalFnOverall{1724}
# \def\rhoZeroNineFilteredRecallOverall{0.805}
# \def\rhoZeroNineFilteredPrecisionOverall{0.786}
# \def\rhoZeroNineFilteredFscoreOverall{0.795}
#
# % --- RhoZeroNineFiltered Variables for Index: percentageMotifsOverLog ---
# \def\rhoZeroNineFilteredPrecisionPercentageMotifsOverLogTwoFivePointZero{0.805}
# \def\rhoZeroNineFilteredRecallPercentageMotifsOverLogTwoFivePointZero{0.949}
# \def\rhoZeroNineFilteredFscorePercentageMotifsOverLogTwoFivePointZero{0.871}
# \def\rhoZeroNineFilteredPrecisionPercentageMotifsOverLogFiveZeroPointZero{0.776}
# \def\rhoZeroNineFilteredRecallPercentageMotifsOverLogFiveZeroPointZero{0.766}
# \def\rhoZeroNineFilteredFscorePercentageMotifsOverLogFiveZeroPointZero{0.771}
# \def\rhoZeroNineFilteredPrecisionPercentageMotifsOverLogSevenFivePointZero{0.773}
# \def\rhoZeroNineFilteredRecallPercentageMotifsOverLogSevenFivePointZero{0.703}
# \def\rhoZeroNineFilteredFscorePercentageMotifsOverLogSevenFivePointZero{0.736}
#
# % --- RhoZeroNineFiltered Variables for Index: noOfMotifs ---
# \def\rhoZeroNineFilteredPrecisionNoOfMotifsOnePointZero{0.993}
# \def\rhoZeroNineFilteredRecallNoOfMotifsOnePointZero{0.994}
# \def\rhoZeroNineFilteredFscoreNoOfMotifsOnePointZero{0.993}
# \def\rhoZeroNineFilteredPrecisionNoOfMotifsTwoPointZero{0.820}
# \def\rhoZeroNineFilteredRecallNoOfMotifsTwoPointZero{0.810}
# \def\rhoZeroNineFilteredFscoreNoOfMotifsTwoPointZero{0.815}
# \def\rhoZeroNineFilteredPrecisionNoOfMotifsThreePointZero{0.787}
# \def\rhoZeroNineFilteredRecallNoOfMotifsThreePointZero{0.795}
# \def\rhoZeroNineFilteredFscoreNoOfMotifsThreePointZero{0.791}
# \def\rhoZeroNineFilteredPrecisionNoOfMotifsFivePointZero{0.733}
# \def\rhoZeroNineFilteredRecallNoOfMotifsFivePointZero{0.770}
# \def\rhoZeroNineFilteredFscoreNoOfMotifsFivePointZero{0.751}
#
# % --- RhoZeroNineFiltered Variables for Index: motOcc ---
# \def\rhoZeroNineFilteredPrecisionMotOccFivePointZero{0.790}
# \def\rhoZeroNineFilteredRecallMotOccFivePointZero{0.756}
# \def\rhoZeroNineFilteredFscoreMotOccFivePointZero{0.773}
# \def\rhoZeroNineFilteredPrecisionMotOccOneZeroPointZero{0.772}
# \def\rhoZeroNineFilteredRecallMotOccOneZeroPointZero{0.798}
# \def\rhoZeroNineFilteredFscoreMotOccOneZeroPointZero{0.785}
# \def\rhoZeroNineFilteredPrecisionMotOccOneFivePointZero{0.794}
# \def\rhoZeroNineFilteredRecallMotOccOneFivePointZero{0.826}
# \def\rhoZeroNineFilteredFscoreMotOccOneFivePointZero{0.810}
#
# % --- RhoZeroNineFiltered Variables for Index: motLength ---
# \def\rhoZeroNineFilteredPrecisionMotLengthOneZeroPointZero{0.808}
# \def\rhoZeroNineFilteredRecallMotLengthOneZeroPointZero{0.801}
# \def\rhoZeroNineFilteredFscoreMotLengthOneZeroPointZero{0.805}
# \def\rhoZeroNineFilteredPrecisionMotLengthTwoZeroPointZero{0.861}
# \def\rhoZeroNineFilteredRecallMotLengthTwoZeroPointZero{0.892}
# \def\rhoZeroNineFilteredFscoreMotLengthTwoZeroPointZero{0.876}
# \def\rhoZeroNineFilteredPrecisionMotLengthFiveZeroPointZero{0.688}
# \def\rhoZeroNineFilteredRecallMotLengthFiveZeroPointZero{0.719}
# \def\rhoZeroNineFilteredFscoreMotLengthFiveZeroPointZero{0.703}
#
# % --- RhoZeroNineFiltered Variables for Index: motShuffle ---
# \def\rhoZeroNineFilteredPrecisionMotShuffleZeroPointZero{0.786}
# \def\rhoZeroNineFilteredRecallMotShuffleZeroPointZero{0.813}
# \def\rhoZeroNineFilteredFscoreMotShuffleZeroPointZero{0.800}
# \def\rhoZeroNineFilteredPrecisionMotShuffleZeroPointOne{0.763}
# \def\rhoZeroNineFilteredRecallMotShuffleZeroPointOne{0.779}
# \def\rhoZeroNineFilteredFscoreMotShuffleZeroPointOne{0.771}
# \def\rhoZeroNineFilteredPrecisionMotShuffleZeroPointTwo{0.810}
# \def\rhoZeroNineFilteredRecallMotShuffleZeroPointTwo{0.822}
# \def\rhoZeroNineFilteredFscoreMotShuffleZeroPointTwo{0.816}
#
# % --------------------------------------------------------
